# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier as dtc

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("Train.csv")
samplesubmission = pd.read_csv("SampleSubmission.csv")

test.isnull().sum().any(), train.isnull().sum().any(), samplesubmission.isnull().sum().any()
# Out:
# (False, False, False)

# %%
train
# Out:
#                  ID  I/O Data Operations   I/O Data Bytes  \
# 0     ID_4W8AP96UO6           114.798900      3790.450939
# 1     ID_UD3TM0ZYND            14.154240      5182.451722
# 2     ID_XAG1HC0HWM             0.044444       120.821253
# 3     ID_CEXD05IR09            31.369916    127228.251100
# 4     ID_X6E97FT8IF             5.046181      1091.620117
# ...             ...                  ...              ...
# 8903  ID_XJWM9B7X4L            26.769658      6965.281426
# 8904  ID_YIC5VRPLUD             0.000000         0.000000
# 8905  ID_T3RF72SEG1             0.866827       853.957842
# 8906  ID_2AUQFJYWKV             0.044430        16.527885
# 8907  ID_LVH8ZOJXLJ             1.155529       192.706713
#
#       Number of subprocesses  Time on processor  Disk Reading/sec  \
# 0                       28.0           0.427078          6.162365
# 1                       28.0           0.138876          5.399498
# 2                       28.0           0.000000          1.577765
# 3                       31.0           0.523750         15.981107
# 4                       25.0           0.069468          1.356022
# ...                      ...                ...               ...
# 8903                    25.0           0.155955          1.497184
# 8904                    27.0           0.000000          0.400009
# 8905                    29.0           0.000000          4.378587
# 8906                    28.0           0.000000          0.888596
# 8907                    27.0           0.000000          0.555543
#
#       Disc Writing/sec  Bytes Sent/sent  Received Bytes (HTTP)  \
# 0            21.220403        58.492773              63.959387
# 1             0.000000        22.886762              29.508369
# 2             0.000000        11.733239              12.888786
# 3             5.356671       602.125436            6976.986795
# 4             0.000000        16.138887              13.271234
# ...                ...              ...                    ...
# 8903          0.000000       252.525113             589.072219
# 8904          0.000000        28.089513              27.267273
# 8905          0.000000        20.559356              26.093712
# 8906          0.000000        74.375484             116.650437
# 8907          0.000000        82.064794              61.909698
#
#       Network packets sent  Network packets received  Pages Read/sec  \
# 0                 0.621206                  0.521813       24.624612
# 1                 0.422183                  0.444403        0.044440
# 2                 0.177776                  0.155554        0.044444
# 3                 3.311801                  5.756755        5.623394
# 4                 0.155609                  0.133379        0.000000
# ...                    ...                       ...             ...
# 8903              0.858386                  0.758573        0.019962
# 8904              0.400009                  0.355563        0.000000
# 8905              0.333395                  0.355621        0.022226
# 8906              0.555372                  0.377653        0.000000
# 8907              1.044421                  0.866647        0.000000
#
#       Pages Input/sec  Page Errors/sec  Confirmed byte radius  Label
# 0                 0.0      1001.533430              27.190843      1
# 1                 0.0      1089.121009              30.150941      0
# 2                 0.0       322.464081              28.163287      0
# 3                 0.0     12015.169690              34.204404      0
# 4                 0.0       550.989619              31.466889      1
# ...               ...              ...                    ...    ...
# 8903              0.0      1177.825039              30.875026      1
# 8904              0.0       221.249363              23.503856      0
# 8905              0.0       262.270699              21.060478      0
# 8906              0.0       268.222697              24.775056      0
# 8907              0.0       289.482282              31.735209      0
#
# [8908 rows x 16 columns]

# %%
X = train.drop(columns=["ID", "I/O Data Operations", "Label"])
y = train['Label']

# %%
model = dtc()
model.fit(X, y) 
model.predict([[24535]])
# Out:
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\micha\OneDrive\Documents\GitHub\machine-learning\cryptojacking\ML-model.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/micha/OneDrive/Documents/GitHub/machine-learning/cryptojacking/ML-model.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> model = dtc()
#       <a href='vscode-notebook-cell:/c%3A/Users/micha/OneDrive/Documents/GitHub/machine-learning/cryptojacking/ML-model.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> model.fit(X, y)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/micha/OneDrive/Documents/GitHub/machine-learning/cryptojacking/ML-model.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> model.predict([[24535]])
#
# File c:\Users\micha\anaconda3\lib\site-packages\sklearn\tree\_classes.py:467, in BaseDecisionTree.predict(self, X, check_input)
#     444 """Predict class or regression value for X.
#     445
#     446 For a classification model, the predicted class for each sample in X is
#    (...)
#     464     The predicted classes, or the predict values.
#     465 """
#     466 check_is_fitted(self)
# --> 467 X = self._validate_X_predict(X, check_input)
#     468 proba = self.tree_.predict(X)
#     469 n_samples = X.shape[0]
#
# File c:\Users\micha\anaconda3\lib\site-packages\sklearn\tree\_classes.py:433, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     431 """Validate the training data on predict (probabilities)."""
#     432 if check_input:
# --> 433     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434     if issparse(X) and (
#     435         X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     436     ):
#     437         raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\micha\anaconda3\lib\site-packages\sklearn\base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File c:\Users\micha\anaconda3\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 1 features, but DecisionTreeClassifier is expecting 13 features as input.
